# %% [markdown]
# <a href="https://colab.research.google.com/github/Shindiya/THE-SPARKS-FOUNDATION/blob/main/OPTICAL_CHAR_RECOGNITION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Graduate Rotational Internship Program @The Sparks Foundation**

# %% [markdown]
# **Task 1:   OPTICAL CHARACTER RECOGNITION**
# CHARACTER DETECTIOR WHICH EXTRACTS PRINTED OR HANDWRITTEN TEXT FROM AN IMAGE

# %% [markdown]
# AUTHOR:SHINDIYA.M
#
# IMPORTING THE REQUIRED LIBRARIES

# %%
import cv2 as cv
import matplotlib.pyplot as plt

# %%
# !sudo apt install tesseract-ocr
# !pip install pytesseract

# %%
import pytesseract
import shutil
import os
import random
try:
 from PIL import Image
except ImportError:
 import Image

# %% [markdown]
# **uploading the image**

# %%
img = cv.imread("gandhi.jpeg")
plt.imshow(img)

# %% [markdown]
# **Convert image to grayscale**

# %%
gray = cv.cvtColor(img,cv.COLOR_BGR2GRAY)
plt.imshow(gray)

# %% [markdown]
# **Extaction of the text**

# %%
TXT=pytesseract.image_to_string(gray)
TXT
# Out:
# '“You must be the\nchange you wish to\nsee in the world.”\n\nMAHATMA GANDHI\n\n \n\x0c'

# %% [markdown]
# **End**
